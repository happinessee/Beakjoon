# %%
import ccxt
import pprint
import numpy as np
import pandas as pd
import datetime

binance = ccxt.binance({
    'apiKey' : 'vDiLBxzA2VPlSuBLYXiDF47mScyldTANFIdysXlZYbVtcM9MA7g65F0EKPwG1w9k',
    'secret' : '3gs0sLJ0HnLsHBmcnqEKH46nEklakikZubDefJEbK8wOusHA8XiDtYj0Xw6LrnLY',
})


# 선물 잔고 가져오기
balance = binance.fetch_balance(params = {'type': 'future'})

print(balance['USDT'])

# 전체 시드의 50%는 포지션 금액으로 설정
positionSeed = (balance['USDT']['free']) / 2


btc_ohlcv = binance.fetch_ohlcv("BTC/USDT", '1d')

df = pd.DataFrame(btc_ohlcv, columns=['datetime', 'open', 'high', 'low', 'close', 'volume'])
df['datetime'] = pd.to_datetime(df['datetime'], unit='ms')
df.set_index('datetime', inplace=True)
print(df)

# ticker, k 값 지정
# 변동폭을 계산해 상승이면 롱, 하락이면 숏을 들어갈 수 있게 하기 위한 함수 

# 변동폭보다 높은 가격 (롱 가격)
def get_higher_price(ticker, k) :
    
    btc_ohlcv = binance.fetch_ohlcv(ticker, '1d')
    target_price = btc_ohlcv[498][4] + (btc_ohlcv[498][2] - btc_ohlcv[498][3]) * k
    return target_price

# 변동폭보다 낮은 가격 (숏 가격)
def get_lower_price(ticker, k) :
    
    btc_ohlcv = binance.fetch_ohlcv(ticker, '1d')
    target_price = btc_ohlcv[498][4] - (btc_ohlcv[498][2] - btc_ohlcv[498][3]) * k
    return target_price

# 시작 시간 조회
def get_start_time(ticker) :
    
    btc_ohlcv = binance.fetch_ohlcv(ticker, '1d')
    start_time = btc_ohlcv[499][0]
    return start_time


# 현재가 조회
def get_current_price(ticker) :
    
    temp = binance.fetch_ticker(ticker)    # 24시간 내의 코인 가격 기본 정보를 가져온다. -> close가 가장 최근에 거래되었던 현재가
    return temp['close']


# 프로그램 시작

# 파라미터 설정
ticker = 'BTC/USDT'
k = 0.5

# while True :
    
#     now = datetime.datetime.now()
#     start_time = get_start_time(ticker)
#     end_time = start_time + 86400
    
#     if start_time < now < end_time :
        
#         currentPrice = get_current_price(ticker) # 현재 비트코인 가격
#         longPrice = get_higher_price(ticker, k)  # long 포지션을 들어가야 하는 가격
#         shortPrice = get_lower_price(ticker, k)  # short 포지션을 들어가야 하는 가격
    
#         # 시드의 50%를 이용해야 하므로 구해준다. positionSeed 는 seed의 50%
#         use50Seed = currentPrice / positionSeed
        
        
#     if (currentPrice >= longPrice) :
#         binance.create_market_buy_order(symbol= ticker, 
#                                         amount= use50Seed,  
#                                         params={'type': 'future'})
        
#     elif (currentPrice <= lowerPrice) : 
#         binance.create_market_sell_order(symbol = ticker,
#                                         amount = use50Seed,
#                                         params={'type': 'future'})
        
    
    
    
        
    





print(get_higher_price(ticker, k))
print(get_lower_price(ticker, k))
print(get_current_price(ticker))

btc_ohlcv1 = binance.fetch_ohlcv('ETH/USDT', '1d')
print(btc_ohlcv1)
# Out:
# {'free': 98.67944232, 'used': 0.0, 'total': 98.67944232}
#                 open      high       low     close         volume
# datetime
# 2020-01-01   7195.24   7255.00   7175.15   7200.85   16792.388165
# 2020-01-02   7200.77   7212.50   6924.74   6965.71   31951.483932
# 2020-01-03   6965.49   7405.00   6871.04   7344.96   68428.500451
# 2020-01-04   7345.00   7404.00   7272.21   7354.11   29987.974977
# 2020-01-05   7354.19   7495.00   7318.00   7358.75   38331.085604
# ...              ...       ...       ...       ...            ...
# 2021-05-10  58240.83  59500.00  53400.00  55816.14   89586.349250
# 2021-05-11  55816.14  56862.43  54370.00  56670.02   64329.540550
# 2021-05-12  56670.02  58000.01  48600.00  49631.32   99842.789836
# 2021-05-13  49537.15  51367.19  46000.00  49670.97  147332.002121
# 2021-05-14  49671.92  50958.32  48799.75  50554.55   42379.857054
#
# [500 rows x 5 columns]
# 52354.565
# 46987.375
# 50551.63
# [[1577836800000, 129.16, 133.05, 128.68, 130.77, 144770.52197], [1577923200000, 130.72, 130.78, 126.38, 127.19, 213757.05806], [1578009600000, 127.19, 135.14, 125.88, 134.35, 413055.18895], [1578096000000, 134.37, 135.85, 132.5, 134.2, 184276.17102], [1578182400000, 134.2, 138.19, 134.19, 135.37, 254120.45343], [1578268800000, 135.37, 144.41, 134.86, 144.15, 408020.27375], [1578355200000, 144.14, 145.31, 138.76, 142.8, 447762.17281], [1578441600000, 142.8, 147.77, 137.03, 140.72, 570465.57764], [1578528000000, 140.76, 141.5, 135.3, 137.74, 366076.06569], [1578614400000, 137.73, 145.17, 135.32, 144.84, 409403.59507], [1578700800000, 144.83, 148.05, 142.09, 142.38, 368350.57939], [1578787200000, 142.4, 146.6, 141.76, 146.54, 229541.86137], [1578873600000, 146.56, 147.0, 142.27, 143.58, 207996.61865], [1578960000000, 143.58, 171.7, 143.51, 165.64, 1108476.31186], [1579046400000, 165.6, 171.98, 159.2, 166.4, 721687.80381], [1579132800000, 166.4, 167.4, 157.8, 164.21, 456170.86719], [1579219200000, 164.24, 174.81, 162.14, 169.85, 767180.67853], [1579305600000, 169.92, 179.5, 164.92, 174.14, 688783.17982], [1579392000000, 174.1, 178.05, 161.66, 166.79, 624681.28604], [1579478400000, 166.79, 169.33, 161.24, 166.87, 358092.8841], [1579564800000, 166.86, 170.32, 164.8, 169.49, 308007.6353], [1579651200000, 169.48, 171.47, 166.03, 168.07, 272240.90286], [1579737600000, 168.07, 168.2, 159.21, 162.81, 373414.34985], [1579824000000, 162.85, 164.45, 155.55, 162.54, 430013.19902], [1579910400000, 162.51, 162.79, 157.61, 160.35, 219921.65197], [1579996800000, 160.36, 168.08, 159.41, 167.86, 251582.55758], [1580083200000, 167.91, 172.56, 165.22, 170.08, 365894.81917], [1580169600000, 170.04, 176.2, 170.03, 175.64, 473433.89609], [1580256000000, 175.58, 178.45, 173.33, 173.72, 317382.90161], [1580342400000, 173.68, 187.0, 170.93, 184.69, 477721.6609], [1580428800000, 184.71, 185.82, 175.22, 179.99, 385596.53365], [1580515200000, 179.94, 184.28, 179.23, 183.6, 259370.12902], [1580601600000, 183.63, 193.43, 179.1, 188.44, 552621.13619], [1580688000000, 188.48, 195.19, 186.62, 189.69, 417175.95781], [1580774400000, 189.74, 191.6, 184.69, 188.91, 366389.69686], [1580860800000, 188.91, 207.61, 188.19, 203.78, 550942.11417], [1580947200000, 203.78, 216.33, 201.02, 213.19, 608240.2233], [1581033600000, 213.16, 225.0, 213.14, 223.33, 629361.15466], [1581120000000, 223.36, 227.75, 213.22, 223.05, 548551.87465], [1581206400000, 223.01, 230.65, 222.86, 228.49, 350336.24399], [1581292800000, 228.53, 229.4, 216.37, 222.89, 510415.49949], [1581379200000, 222.89, 239.15, 218.17, 236.69, 595576.90276], [1581465600000, 236.69, 275.34, 236.69, 265.74, 1038073.74782], [1581552000000, 265.74, 277.69, 256.08, 268.32, 1089679.1537], [1581638400000, 268.34, 287.15, 260.28, 285.15, 734944.32266], [1581724800000, 285.11, 288.41, 261.86, 264.88, 860813.14274], [1581811200000, 264.91, 274.0, 237.41, 258.85, 1110118.46395], [1581897600000, 258.89, 268.77, 242.0, 267.85, 1110371.39094], [1581984000000, 267.9, 285.88, 258.0, 282.61, 1115523.43992], [1582070400000, 282.64, 285.0, 251.56, 258.45, 705973.72988], [1582156800000, 258.44, 264.33, 245.34, 256.96, 972969.71691], [1582243200000, 256.97, 268.24, 253.61, 265.27, 525827.8734], [1582329600000, 265.32, 266.81, 256.0, 261.57, 313062.52133], [1582416000000, 261.55, 275.68, 261.02, 274.48, 444740.82883], [1582502400000, 274.5, 277.2, 257.09, 265.52, 696591.72983], [1582588800000, 265.47, 266.22, 244.44, 246.67, 774791.01027], [1582675200000, 246.67, 250.32, 215.66, 223.93, 1395879.41507], [1582761600000, 223.98, 238.3, 210.0, 227.79, 1273793.11658], [1582848000000, 227.73, 234.67, 214.01, 226.76, 1054994.92397], [1582934400000, 226.76, 233.0, 217.0, 217.21, 546866.6851], [1583020800000, 217.29, 227.89, 212.36, 217.81, 715016.01941], [1583107200000, 217.81, 234.4, 216.07, 231.97, 810051.4833], [1583193600000, 232.1, 232.46, 219.57, 223.91, 741498.54825], [1583280000000, 223.84, 228.85, 220.23, 224.26, 443780.33772], [1583366 ...
